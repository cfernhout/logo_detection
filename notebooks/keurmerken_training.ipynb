# %% [markdown]
# # Training

# %% [markdown]
# ## Import dependencies

# %%
# !pip3 install tensorflow-gpu==1.13.1 --quiet
# !pip install imageai --quiet
# Out:
#      |████████████████████████████████| 345.2MB 48kB/s
#      |████████████████████████████████| 3.2MB 32.2MB/s
#      |████████████████████████████████| 368kB 46.8MB/s
# ERROR: tensorflow 1.15.0 has requirement tensorboard<1.16.0,>=1.15.0, but you'll have tensorboard 1.13.1 which is incompatible.
# ERROR: tensorflow 1.15.0 has requirement tensorflow-estimator==1.15.1, but you'll have tensorflow-estimator 1.13.0 which is incompatible.
#      |████████████████████████████████| 184kB 2.9MB/s

# %%
import os
from google.colab import drive, files
import imageai
from imageai.Detection.Custom import DetectionModelTrainer
# Out:
# Using TensorFlow backend.
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %% [markdown]
# ## Mount drive and set data directories

# %%
drive.mount('/content/drive/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/

# %%
#imageslis = !ls "/content/drive/Shared drives/Class 15/keurmerken-od-training/total/train/images"
#annotationslis = !ls "/content/drive/Shared drives/Class 15/keurmerken-od-training/total/train/annotations"

# %%
# Copy and paste the root of your folder from the side menu
ROOT_DIR = "/content/drive/Shared drives/Class 15/keurmerken-od-training/"

# %% [markdown]
# ## Model type

# %%
# Set model type
trainer = DetectionModelTrainer()
trainer.setModelTypeAsYOLOv3()

# %% [markdown]
# ## Training settings

# %%
# Detect and set class labels
#labels = ['planetproof', 'asc', 'msc', 'eko', 'ebio', 'fairtrade', 'beterleven', 'utz']
labels =  ['planetproof']

# %%
# !ls "/content/drive/Shared drives/Class 15/keurmerken-od-training/planetproof/models"
# Out:
# detection_model-ex-001--loss-0062.055.h5
# detection_model-ex-001--loss-0070.142.h5
# detection_model-ex-002--loss-0025.091.h5
# detection_model-ex-002--loss-0026.833.h5
# detection_model-ex-003--loss-0019.339.h5
# detection_model-ex-003--loss-0020.001.h5
# detection_model-ex-004--loss-0016.791.h5
# detection_model-ex-004--loss-0018.406.h5
# detection_model-ex-005--loss-0015.461.h5
# detection_model-ex-006--loss-0015.368.h5
# detection_model-ex-007--loss-0011.677.h5
# detection_model-ex-008--loss-0010.410.h5
# detection_model-ex-009--loss-0008.728.h5
# detection_model-ex-010--loss-0008.116.h5
# detection_model-ex-011--loss-0008.045.h5
# detection_model-ex-012--loss-0007.945.h5
# detection_model-ex-013--loss-0007.492.h5
# detection_model-ex-014--loss-0006.583.h5
# detection_model-ex-015--loss-0005.755.h5
# detection_model-ex-016--loss-0005.336.h5
# detection_model-ex-017--loss-0005.261.h5
# detection_model-ex-018--loss-0004.947.h5
# detection_model-ex-019--loss-0004.851.h5
# ...

# %%
# !ls datadirectory
# Out:
# ls: cannot access 'datadirectory': No such file or directory

# %%
# Data folder
trainer.setDataDirectory(data_directory = "/content/drive/Shared drives/Class 15/keurmerken-od-training/planetproof/")

# %% [markdown]
# To resume training, copy the directory of your most recent model in `train_from_pretrained_model`.

# %%
# Training configuration
trainer.setTrainConfig(object_names_array = labels,
                       batch_size = 4,
                       num_experiments = 100,
                       train_from_pretrained_model="/content/drive/Shared drives/Class 15/keurmerken-od-training/planetproof/models/detection_model-ex-024--loss-0003.457.h5")
# Out:
# Generating anchor boxes for training images and annotation...
# Average IOU for 9 anchors: 0.81
# Anchor Boxes generated.
# Detection configuration saved in  /content/drive/Shared drives/Class 15/keurmerken-od-training/planetproof/json/detection_config.json

# %%
trainer.trainModel()
# Out:
# Training on: 	['planetproof']
# Training with Batch Size:  4
# Number of Experiments:  100
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/imageai/Detection/Custom/yolo.py:24: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Training with transfer learning from pretrained Model
# /usr/local/lib/python3.6/dist-packages/keras/callbacks.py:1335: UserWarning: `epsilon` argument is deprecated and will be removed, use `min_delta` instead.
#   warnings.warn('`epsilon` argument is deprecated and '
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
